# %% [markdown]
# # Pytorch Lightning Introduction
#
# Welcome to the introduction to [`PyTorchLightning`](https://www.pytorchlightning.ai/). PyTorch Lightning is a wrapper for PyTorch that is focused towards building neural networks model quickly by removing the boilerplate code. It also extends the functionality of PyTorch, for example, with model Callbacks and automatic porting to GPU to accelerate computations.
#
# In its essence, pytorch lightning provides a controlled setup where you are forced to in its specific partly automated library setup, but are able to customize/de-automatate each process if you so desire. You can both rely on a variety of already implemented functionalities and the fact that your code is by definition structured clearly, but at the cost of having to delve into their code structure and figuring out which functions to use.
#
# Our suggestion is to try it out. If you like it, cool, otherwise you can just stick to pytorch and build up your own library of functions you will use throughout your Deep Learning journey.
#
# Let's get started by installing PyTorch Lightning.

# %% [markdown]
# ## (Optional) Mount folder in Colab
#
# Uncomment thefollowing cell to mount your gdrive if you are using the notebook in google colab:

# %%
"""
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/i2dl/exercise_07'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
print(sorted(os.listdir()))
"""
# Out:
# "\nfrom google.colab import drive\nimport os\n\ngdrive_path='/content/gdrive/MyDrive/i2dl/exercise_07'\n\n# This will mount your google drive under 'MyDrive'\ndrive.mount('/content/gdrive', force_remount=True)\n# In order to access the files in this notebook we have to navigate to the correct folder\nos.chdir(gdrive_path)\n# Check manually if all files are present\nprint(sorted(os.listdir()))\n"

# %%
# Optional: install correct libraries in google colab
# !python -m pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html
# !python -m pip install tensorboard==2.9.1

# %% [markdown]
# ### Installing Pytorch Lightning

# %%
# For automatic file reloading as usual
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys

# For google colab
# !python -m pip install pytorch-lightning==1.6.0 > /dev/null

# For anaconda/regular python
# !{sys.executable} -m pip install --ignore-installed pytorch-lightning==1.6.0
# Out:
# Collecting pytorch-lightning==1.6.0
#   Downloading pytorch_lightning-1.6.0-py3-none-any.whl (582 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.1/582.1 KB 5.3 MB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting packaging>=17.0
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Collecting pyDeprecate<0.4.0,>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting typing-extensions>=4.0.0
#   Using cached typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 4.6 MB/s eta 0:00:00
# Collecting numpy>=1.17.2
#   Downloading numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 10.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting tqdm>=4.41.0
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 5.8 MB/s eta 0:00:00
# Collecting PyYAML>=5.4
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 KB 10.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting tensorboard>=2.2.0
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Collecting torch>=1.8.*
#   Downloading torch-1.12.0-cp310-cp310-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 5.6 MB/s eta 0:00:00m eta 0:00:010:00:03
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.2-py3-none-any.whl (419 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.7/419.7 KB 9.8 MB/s eta 0:00:000:00:01
# Collecting requests
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.7 MB/s eta 0:00:0010.9 MB/s eta 0:00:01
# Collecting pyparsing!=3.0.5,>=2.0.2
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 KB 6.8 MB/s eta 0:00:00
# Collecting setuptools>=41.0.0
#   Downloading setuptools-62.6.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.2 MB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting wheel>=0.26
#   Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting absl-py>=0.4
#   Using cached absl_py-1.1.0-py3-none-any.whl (123 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.1.2-py3-none-any.whl (224 kB)
# Collecting grpcio>=1.24.3
#   Using cached grpcio-1.47.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.7-py3-none-any.whl (97 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.9.0-py2.py3-none-any.whl (167 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting six>=1.9.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.8-py3-none-any.whl (39 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.0-py3-none-any.whl (39 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.6.15-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.2/160.2 KB 7.8 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.9/157.9 KB 7.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-21.4.0-py2.py3-none-any.whl (60 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (305 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.3/305.3 KB 9.3 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 7.1 MB/s eta 0:00:00
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Installing collected packages: tensorboard-plugin-wit, pyasn1, wheel, werkzeug, urllib3, typing-extensions, tqdm, tensorboard-data-server, six, setuptools, rsa, PyYAML, pyparsing, pyDeprecate, pyasn1-modules, protobuf, oauthlib, numpy, multidict, markdown, idna, fsspec, frozenlist, charset-normalizer, certifi, cachetools, attrs, async-timeout, absl-py, yarl, torch, requests, packaging, grpcio, google-auth, aiosignal, torchmetrics, requests-oauthlib, aiohttp, google-auth-oauthlib, tensorboard, pytorch-lightning
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.12.0+cu113 requires torch==1.11.0, but you have torch 1.12.0 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.12.0 which is incompatible.
# Successfully installed PyYAML-6.0 absl-py-1.1.0 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 attrs-21.4.0 cachetools-5.2.0 certifi-2022.6.15 charset-normalizer-2.1.0 frozenlist-1.3.0 fsspec-2022.5.0 google-auth-2.9.0 google-auth-oauthlib-0.4.6 grpcio-1.47.0 idna-3.3 markdown-3.3.7 multidict-6.0.2 numpy-1.23.0 oauthlib-3.2.0 packaging-21.3 protobuf-3.19.4 pyDeprecate-0.3.2 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyparsing-3.0.9 pytorch-lightning-1.6.0 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.8 setuptools-62.6.0 six-1.16.0 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 torch-1.12.0 torchmetrics-0.9.2 tqdm-4.64.0 typing-extensions-4.3.0 urllib3-1.26.9 werkzeug-2.1.2 wheel-0.37.1 yarl-1.7.2
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/home/ml/anaconda3/envs/i2dl/bin/python -m pip install --upgrade pip' command.

# %%
import pytorch_lightning as pl
print(f"Lightning version: {pl.__version__}")
if not pl.__version__.startswith("1.6"):
    print("You are using another version of pytorch lightning. We expect pytorch lightning 1.6.0. You can continue with your version but it"
          " might cause dependency and compatibility issues.")

import tensorboard
import torch
import torchvision
print(f"Tensorboard version: {tensorboard.__version__}")
if not tensorboard.__version__.startswith("2.9.1"):
    print("You are using an another version of Tensorboard. We expect Tensorboard 2.9.1 You may continue using your version but it"
          " might cause dependency and compatibility issues.")
print(f"PyTorch version Installed: {torch.__version__}\nTorchvision version Installed: {torchvision.__version__}\n")
if not torch.__version__.startswith("1.11"):
    print("you are using an another version of PyTorch. We expect PyTorch 1.11.0. You may continue using your version but it"
          " might cause dependency and compatibility issues.")
if not torchvision.__version__.startswith("0.12"):
    print("you are using an another version of torchvision. We expect torchvision 0.12. You can continue with your version but it"
          " might cause dependency and compatibility issues.")
# Out:
# Lightning version: 1.6.0
# Tensorboard version: 2.9.1
# PyTorch version Installed: 1.12.0+cu102
# Torchvision version Installed: 0.12.0+cu113
#
# you are using an another version of PyTorch. We expect PyTorch 1.11.0. You may continue using your version but it might cause dependency and compatibility issues.
# /home/ml/anaconda3/envs/i2dl/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")

# %% [markdown]
# # 1. Idea behind PyTorch Lightning
#
# Codes in a Deep learning project consists of three main categories:
#
# 1. **Research code**
#     This is the exciting part of the experiment where you configure the model architecture and try out different optimizers and target task. This is managed by the `LightningModule` of PyTorch Lightning.
#
# 2. **Engineering code**
#     This is the same set of code that remain the same for all deep learning projects.Recall the training block of previous notebooks where we loop through the epochs and mini-batches. The `Trainer` class of PyTorch Lightning takes care of this part of code.
#
# 3. **Non-essential code**
#     It is very important that we log our training metrics and organize different training runs to have purposeful experimentation of models. The `Callbacks` class PyTorch Lightning helps us with this section.
#
# Let's look at each of these modules in detail.
#
# 1. **LightningModules** contain all model related code. This is the part where we are working on when creating a new project. The idea is to have all important code in one module, e.g., the model's architecture and the evaluation of training and validation metrics. This provides a better overview as repeated elements, such as the training procedure, are not stored in the code that we work on. The lightning module also handles the calls `.to(device)` or `.train()` and `.eval()`. Hence, there is no need anymore to switch between the cpu and gpu and to take care of the model's mode as this is automated by the LightningModule. The framework also enables easy parallel computation on multiple gpus.
#
# 2. **Trainer** contains all code needed for training our neural networks that doesn't change for each project ("one size fits all"). Usually, we don't touch the code automated by this class. The arguments that are specific for one training such as learning rate and batch size are provided as initialization arguments for the LightningModule.
#
# 3. **Callbacks** automate all parts needed for logging hyperparameters or training results such as the tensorboard logger. Logging becomes very important for research later since the results of experiments need to be reproducible.
#
# All in all, PyTorch is a framework that handles all (annoying) "engineering" stuff for you such that you have more time for exciting research and scientific coding. This also results in the advantage that automated parts are guaranteed to be bug-free. Hence, you can't include a bug in a part of your code that is often used but not often checked.

# %% [markdown]
# # 2. Overview of the PyTorch Lightning code

# %% [markdown]
# Research relevant code goes into the `LightningModule`. The advantage is that we have all the model building, training & validation steps within a single class. These are the components that usually change based on the projects and tasks.

# %% [markdown]
# ![tensorBoard Interface](./images/pl_quick_start_full_compressed.gif)

# %% [markdown]
# The remaining code is automated by the `Trainer` class which takes care of the tasks of our mechanical training loops components such as iterating through the minibatches and gradient updating steps.

# %% [markdown]
# ![alt text](https://miro.medium.com/max/700/1*b81_j__xv8M0Bb6nFTXbAA.png)

# %% [markdown]
# We could already see how much more readable and concise our code is, after being transformed by PyTorch Lightning.
#
# Let us now train a neural network model with PyTorch Lightning.

# %% [markdown]
# # 4. Training with PyTorch Lightning
#
# We will build a two-layer neural network to train on the the [`Fashion-MNIST`](https://research.zalando.com/welcome/mission/research-projects/fashion-mnist/) dataset for this notebook.
#
# ## 4.1 Define A LightningModule
#
# We define our network as an instance of `pl.LightningModule` which replaces our `PyTorch` network based on the class `nn.Module`. Additionally, it contains all the relevant parts that are used for training and evaluating different models on various tasks.
#
# Let's have a look at the implementation of `TwoLayerNet` in `exercise_code.lightning_models`.

# %% [markdown]
# The `__init__()` and `forward()` function defining the forward  pass remain the same. Hence, we can just copy the code from the `nn.Module`.

# %% [markdown]
# ```python
# class TwoLayerNet(pl.LightningModule):
#     def __init__(self, hparams, input_size=1 * 28 * 28, hidden_size=512, num_classes=10):
#         super().__init__()
#         self.save_hyperparameters(hparams)
#
#         self.model = nn.Sequential(
#             nn.Linear(input_size, hidden_size),
#             nn.Sigmoid(),
#             nn.Linear(hidden_size, num_classes),
#         )
#
#     def forward(self, x):
#         # flatten the image  before sending as input to the model
#         N, _, _, _ = x.shape
#         x = x.view(N, -1)
#
#         x = self.model(x)
#
#         return x
# ```

# %% [markdown]
# We will now define the training  and validation steps since they also vary with different tasks and projects. Consequently, it is useful to integrate these parts into our instance of `LightningModule`. Validation loss is returned for each validation mini-batch and averaged at the end of the epoch.

# %% [markdown]
# ```python
#     def training_step(self, batch, batch_idx):
#         images, targets = batch
#
#         # Perform a forward pass on the network with inputs
#         out = self.forward(images)
#
#         # calculate the loss with the network predictions and ground truth targets
#         loss = F.cross_entropy(out, targets)
#
#         # Find the predicted class from probabilities of the image belonging to each of the classes
#         # from the network output
#         _, preds = torch.max(out, 1)
#
#         # Calculate the accuracy of predictions
#         acc = preds.eq(targets).sum().float() / targets.size(0)
#
#         # Log the accuracy and loss values to the tensorboard
#         self.log('loss', loss)
#         self.log('acc', acc)
#
#         return {'loss': loss}
#
#     def validation_step(self, batch, batch_idx):
#         images, targets = batch
#
#         # Perform a forward pass on the network with inputs
#         out = self.forward(images)
#
#         # calculate the loss with the network predictions and ground truth targets
#         loss = F.cross_entropy(out, targets)
#
#         # Find the predicted class from probabilities of the image belonging to each of the classes
#         # from the network output
#         _, preds = torch.max(out, 1)
#
#         # Calculate the accuracy of predictions
#         acc = preds.eq(targets).sum().float() / targets.size(0)
#
#         # Visualise the predictions  of the model
#         if batch_idx == 0:
#             self.visualize_predictions(images, out.detach(), targets)
#
#         return {'val_loss': loss, 'val_acc': acc}
#
#     def validation_epoch_end(self, outputs):
#
#         # Average the loss over the entire validation data from it's mini-batches
#         avg_loss = torch.stack([x['val_loss'] for x in outputs]).mean()
#         avg_acc = torch.stack([x['val_acc'] for x in outputs]).mean()
#
#         # Log the validation accuracy and loss values to the tensorboard
#         self.log('val_loss', avg_loss)
#         self.log('val_acc', avg_acc)
# ```

# %% [markdown]
# The last step missing in our `LightningModule` is the optimizer. This method needs to be defined in every `LightningModule`.

# %% [markdown]
# ```python
#     def configure_optimizers(self):
#         optim = torch.optim.SGD(self.model.parameters(), self.hparams["learning_rate"], momentum=0.9)
#
#         return optim
# ```

# %% [markdown]
# Now that we have set up the model and the training steps, we will now establish the data pipeline. PyTorch Lightning provides the `LightningDataModule` for setting up the dataloaders.
#
# Let's have a look at the implementation of `FashionMNISTDataModule` in `exercise_code.data_class`.
#
# The `prepare_data()` function intends to set up the dataset and the related transforms for it. As previously, we download the `FashionMNIST` dataset using `torchvision` and split the total training data into a training and validation set for tuning hyperparameters.

# %% [markdown]
# ```python
# class FashionMNISTDataModule(pl.LightningDataModule):
#
#     def __init__(self, batch_size=4):
#         super().__init__()
#         self.batch_size = batch_size
#
#     def prepare_data(self):
#
#         # Define the transform
#         transform = transforms.Compose([transforms.ToTensor(),
#                                         transforms.Normalize((0.5,), (0.5,))])
#
#         # Download the Fashion-MNIST dataset
#         fashion_mnist_train_val = torchvision.datasets.FashionMNIST(root='../datasets', train=True,
#                                                                    download=True, transform=transform)
#
#         self.fashion_mnist_test = torchvision.datasets.FashionMNIST(root='../datasets', train=False,
#                                                                  download=True, transform=transform)
#
#         # Apply the Transforms
#         transform = transforms.Compose([transforms.ToTensor(),
#                                         transforms.Normalize((0.5,), (0.5,))])
#
#         # Perform the training and validation split
#         self.train_dataset, self.val_dataset = random_split(
#             fashion_mnist_train_val, [50000, 10000])
# ```

# %% [markdown]
# We shall now define `Dataloaders` for each of the data-splits. These data loaders can be directly called during model training!

# %% [markdown]
# ```python
#
#     def train_dataloader(self):
#         return DataLoader(self.train_dataset, batch_size=self.batch_size)
#
#     def val_dataloader(self):
#         return DataLoader(self.val_dataset, batch_size=self.batch_size)
#
#     def test_dataloader(self):
#         return DataLoader(self.fashion_mnist_test, batch_size=self.batch_size)
#
# ```

# %% [markdown]
# You can notice now that most of the code of these steps can be directly copied from a Vanilla PyTorch code. Lightning just rearranges them. This marks the end of the research part of the code.
#
# Let's see now how the `Trainer` class works:

# %% [markdown]
# ##  4.2 Fitting the model with a Trainer

# %% [markdown]
# We will initialize the model and the data  with a set of hyperparameters given in the dictionary `hparams`.

# %%
from IPython.display import clear_output 

from exercise_code.lightning_models import TwoLayerNet
from exercise_code.data_class import FashionMNISTDataModule

hparams = {
    "batch_size": 16,
    "learning_rate": 1e-3,
    "input_size": 1 * 28 * 28,
    "hidden_size": 512,
    "num_classes": 10,
    "num_workers": 2,    # used by the dataloader, more workers means faster data preparation, but for us this is not a bottleneck here
}


model = TwoLayerNet(hparams)
data=FashionMNISTDataModule(hparams)
data.prepare_data()

# %% [markdown]
#  PyTorch Lightning provides ample flexibility for training using [`Trainer`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html) class.
# Have a look at the documentation to know more about them!
#
# Let's initialize it now!

# %%
trainer = pl.Trainer(
    max_epochs=2,
    # Uncomment to use GPU if available, if multiple you can select all indices, otherwise we use the first, -1 is CPU
    # devices='0' 
)
# Out:
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /home/ml/anaconda3/envs/i2dl/lib/python3.10/site-packages/pytorch_lightning/trainer/trainer.py:1823: PossibleUserWarning: GPU available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='gpu', devices=1)`.
#   rank_zero_warn(

# %% [markdown]
# The argument `max_epochs` sets the maximum number of epochs for training.
# The argument `weights_summary` prints a summary of the number of weights per layer at the beginning of the training. Set it to None if the summary is not required.

# %% [markdown]
# Here comes the actual training cell. The [`fit`](https://pytorch-lightning.readthedocs.io/en/latest/_modules/pytorch_lightning/trainer/trainer.html#Trainer.fit) function takes in the model and data to train the model with a lot more optional arguments for customization.

# %%
trainer.fit(model, data)
# Out:
# Missing logger folder: /home/ml/Downloads/exercise_07/lightning_logs
#
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 407 K
# -------------------------------------
# 407 K     Trainable params
# 0         Non-trainable params
# 407 K     Total params
# 1.628     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /home/ml/anaconda3/envs/i2dl/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /home/ml/anaconda3/envs/i2dl/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %% [markdown]
# Checkout the directory `lightning_logs`. For each run there is a new directory `version_xx` created. The rightmost argument in the progress bar, the `v_num` variable above shows the version of the current run. Each directory automatically contains a folder with checkpoints, logs and the hyperparameters for this run.
#
# As seen in the last notebook, you can have a look at the  logs of the runs in the TensorBoard
# Use the command as in the previous notebook in your terminal
# ```
# tensorboard --logdir lightning_logs
# ```
# Make sure to use the above command as the same directory as `exercise_07`.

# %% [markdown]
# If you are using Google Colab, run the following cell to load the TensorBoard extension within the notebook. You may have to scroll to this block whenever you need to look at the TensorBoard interface.

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs

# %% [markdown]
# ## 4.3 Add images to tensorboard

# %% [markdown]
# The tensorboard logger is a submodule of the `LightningModule` and can be accessed via `self.logger`. We can  add images  to the logging module by calling
# ```python
# self.logger.experiment.add_image('tag', image)
# ```
# to add an image.
#
#
# We will log the first batch of validation images in a grid together with the predicted class labels and the ground truth labels.
#
# ```python
#         if batch_idx == 0:
#             self.visualize_predictions(images, out.detach(), targets)
# ```
#
# Let's have a look at the implementation of `visualize_predictions()` function in `exercise_code.lightning_models`.
#
#
#
# ```python
#     def visualize_predictions(self, images, preds, targets):
#         class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
#                        'dog', 'frog', 'horse', 'ship', 'truck']
#
#         # determine size of the grid based on given batch size
#         num_rows = torch.tensor(len(images)).float().sqrt().floor()
#
#         fig = plt.figure(figsize=(10, 10))
#         for i in range(len(images)):
#             plt.subplot(num_rows ,len(images) // num_rows + 1, i+1)
#             plt.imshow(images[i].permute(1, 2, 0))
#             plt.title(class_names[torch.argmax(preds, axis=-1)[i]] + f'\n[{class_names[targets[i]]}]')
#             plt.axis('off')
#
#         self.logger.experiment.add_figure('predictions', fig, global_step=self.global_step)
# ```
#
# You can view the logged images in your `IMAGES` tab of TensorBoard.

# %% [markdown]
# We have now looked at how to train a model using PyTorch Lightning. PyTorch Lightning is very active in developement and the features set are continously expanded and updated.

# %% [markdown]
# # 4. Other Features of PyTorch Lightning
#
#
# ### Checking  training timings
#
# The argument `profiler` of the `Trainer` class measures the time taken in different steps such as dataloading, forward and backward pass. You can select a variety of loggers [here](https://pytorch-lightning.readthedocs.io/en/stable/advanced/profiler.html).
#
# Run the cell below to see for yourself.

# %%
trainer = pl.Trainer(
    profiler='simple',
    max_epochs=1,
    # gpus=1 # Use GPU if available
   
)

trainer.fit(model, data)
# Out:
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 407 K
# -------------------------------------
# 407 K     Trainable params
# 0         Non-trainable params
# 407 K     Total params
# 1.628     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# FIT Profiler Report
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                                                                    	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                                                     	|  -              	|  137063         	|  13.416         	|  100 %          	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                                                        	|  13.026         	|  1              	|  13.026         	|  97.088         	|
# |  run_training_batch                                                                                                                                                                                        	|  0.001518       	|  3125           	|  4.7436         	|  35.357         	|
# |  [LightningModule]TwoLayerNet.optimizer_step                                                                                                                                                               	|  0.0013631      	|  3125           	|  4.2598         	|  31.75          	|
# |  on_train_batch_end                                                                                                                                                                                        	|  0.00093223     	|  3125           	|  2.9132         	|  21.714         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                                                              	|  0.00048221     	|  3125           	|  1.5069         	|  11.232         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                                                                   	|  0.000381       	|  3125           	|  1.1906         	|  8.8745         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                                                            	|  0.0011178      	|  627            	|  0.70085        	|  5.2239         	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                                                         	|  0.00067935     	|  627            	|  0.42595        	|  3.1749         	|
# |  on_train_batch_start                                                                                                                                                                                      	|  0.00010291     	|  3125           	|  0.32159        	|  2.397          	|
# |  [LightningModule]TwoLayerNet.optimizer_zero_grad                                                                                                                                                          	|  5.8047e-05     	|  3125           	|  0.1814         	|  1.3521         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                                                            	|  3.4636e-05     	|  3752           	|  0.12996        	|  0.96863        	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                                                             	|  0.0067354      	|  2              	|  0.013471       	|  0.10041        	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                                                           	|  0.012387       	|  1              	|  0.012387       	|  0.092329       	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                                                                  	|  0.012083       	|  1              	|  0.012083       	|  0.090061       	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                                                               	|  3.6133e-06     	|  3125           	|  0.011291       	|  0.084161       	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                                                             	|  3.1797e-06     	|  3125           	|  0.0099367      	|  0.074064       	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                                                              	|  2.8122e-06     	|  3125           	|  0.0087882      	|  0.065504       	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                                                        	|  2.609e-06      	|  3125           	|  0.0081532      	|  0.060771       	|
# |  [Callback]TQDMProgressBar.on_batch_start                                                                                                                                                                  	|  2.5654e-06     	|  3125           	|  0.0080169      	|  0.059754       	|
# |  [Callback]TQDMProgressBar.on_batch_end                                                                                                                                                                    	|  2.4834e-06     	|  3125           	|  0.0077605      	|  0.057844       	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                                                                  	|  2.4814e-06     	|  3125           	|  0.0077543      	|  0.057797       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_zero_grad                	|  2.3615e-06     	|  3125           	|  0.0073798      	|  0.055006       	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                                                                	|  2.3047e-06     	|  3125           	|  0.0072022      	|  0.053682       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_backward                 	|  2.2382e-06     	|  3125           	|  0.0069942      	|  0.052132       	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                                                                 	|  2.2211e-06     	|  3125           	|  0.0069408      	|  0.051734       	|
# |  [Callback]GradientAccumulationScheduler.on_before_optimizer_step                                                                                                                                          	|  2.2131e-06     	|  3125           	|  0.0069159      	|  0.051549       	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                                                           	|  2.2066e-06     	|  3125           	|  0.0068955      	|  0.051396       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_before_optimizer_step           	|  2.1887e-06     	|  3125           	|  0.0068398      	|  0.050981       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_after_backward                  	|  2.1454e-06     	|  3125           	|  0.0067043      	|  0.049971       	|
# |  [Callback]GradientAccumulationScheduler.on_after_backward                                                                                                                                                 	|  2.1415e-06     	|  3125           	|  0.006692       	|  0.04988        	|
# |  [Callback]GradientAccumulationScheduler.on_before_zero_grad                                                                                                                                               	|  2.12e-06       	|  3125           	|  0.0066251      	|  0.049381       	|
# |  [Callback]GradientAccumulationScheduler.on_before_backward                                                                                                                                                	|  2.0789e-06     	|  3125           	|  0.0064967      	|  0.048423       	|
# |  [Callback]ModelSummary.on_batch_start                                                                                                                                                                     	|  2.0192e-06     	|  3125           	|  0.00631        	|  0.047032       	|
# |  [Callback]GradientAccumulationScheduler.on_batch_start                                                                                                                                                    	|  1.943e-06      	|  3125           	|  0.006072       	|  0.045258       	|
# |  [Callback]ModelSummary.on_batch_end                                                                                                                                                                       	|  1.893e-06      	|  3125           	|  0.0059156      	|  0.044092       	|
# |  [Callback]GradientAccumulationScheduler.on_batch_end                                                                                                                                                      	|  1.883e-06      	|  3125           	|  0.0058843      	|  0.043859       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_batch_start                     	|  1.8472e-06     	|  3125           	|  0.0057726      	|  0.043026       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_batch_end                       	|  1.8371e-06     	|  3125           	|  0.0057409      	|  0.04279        	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_epoch_end                 	|  0.005427       	|  1              	|  0.005427       	|  0.04045        	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                                                       	|  8.3002e-06     	|  627            	|  0.0052042      	|  0.03879        	|
# |  [LightningModule]TwoLayerNet.training_step_end                                                                                                                                                            	|  1.197e-06      	|  3125           	|  0.0037405      	|  0.02788        	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                                                            	|  5.7583e-06     	|  627            	|  0.0036105      	|  0.026911       	|
# |  [Strategy]SingleDeviceStrategy.training_step_end                                                                                                                                                          	|  1.1201e-06     	|  3125           	|  0.0035003      	|  0.02609        	|
# |  [LightningModule]TwoLayerNet.on_train_batch_end                                                                                                                                                           	|  1.071e-06      	|  3125           	|  0.003347       	|  0.024947       	|
# |  [LightningModule]TwoLayerNet.on_after_backward                                                                                                                                                            	|  9.8304e-07     	|  3125           	|  0.003072       	|  0.022897       	|
# |  [LightningModule]TwoLayerNet.on_train_batch_start                                                                                                                                                         	|  9.6767e-07     	|  3125           	|  0.003024       	|  0.022539       	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                                                       	|  8.3443e-07     	|  3125           	|  0.0026076      	|  0.019436       	|
# |  [LightningModule]TwoLayerNet.on_before_backward                                                                                                                                                           	|  8.0697e-07     	|  3125           	|  0.0025218      	|  0.018796       	|
# |  [LightningModule]TwoLayerNet.on_before_zero_grad                                                                                                                                                          	|  7.9043e-07     	|  3125           	|  0.0024701      	|  0.018411       	|
# |  [LightningModule]TwoLayerNet.validation_epoch_end                                                                                                                                                         	|  0.0012173      	|  2              	|  0.0024345      	|  0.018146       	|
# |  [LightningModule]TwoLayerNet.on_before_optimizer_step                                                                                                                                                     	|  7.4301e-07     	|  3125           	|  0.0023219      	|  0.017306       	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                                                          	|  3.1619e-06     	|  627            	|  0.0019825      	|  0.014777       	|
# |  [Callback]GradientAccumulationScheduler.on_validation_batch_end                                                                                                                                           	|  2.366e-06      	|  627            	|  0.0014835      	|  0.011057       	|
# |  [Callback]GradientAccumulationScheduler.on_validation_batch_start                                                                                                                                         	|  2.2185e-06     	|  627            	|  0.001391       	|  0.010368       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_batch_start          	|  2.2144e-06     	|  627            	|  0.0013885      	|  0.010349       	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_batch_end            	|  2.0864e-06     	|  627            	|  0.0013082      	|  0.0097506      	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                                                               	|  0.00064292     	|  2              	|  0.0012858      	|  0.0095842      	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                                                       	|  0.0012765      	|  1              	|  0.0012765      	|  0.0095146      	|
# |  [LightningModule]TwoLayerNet.validation_step_end                                                                                                                                                          	|  1.3834e-06     	|  627            	|  0.00086741     	|  0.0064653      	|
# |  [Strategy]SingleDeviceStrategy.validation_step_end                                                                                                                                                        	|  1.0088e-06     	|  627            	|  0.00063249     	|  0.0047144      	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                                                                    	|  0.0005701      	|  1              	|  0.0005701      	|  0.0042493      	|
# |  [LightningModule]TwoLayerNet.on_validation_batch_start                                                                                                                                                    	|  8.7944e-07     	|  627            	|  0.00055141     	|  0.00411        	|
# |  [LightningModule]TwoLayerNet.on_validation_batch_end                                                                                                                                                      	|  8.282e-07      	|  627            	|  0.00051928     	|  0.0038705      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                                                            	|  0.00040523     	|  1              	|  0.00040523     	|  0.0030204      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                                                              	|  0.00035739     	|  1              	|  0.00035739     	|  0.0026638      	|
# |  [LightningModule]TwoLayerNet.on_validation_model_train                                                                                                                                                    	|  5.0267e-05     	|  2              	|  0.00010053     	|  0.00074933     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.setup                              	|  9.8245e-05     	|  1              	|  9.8245e-05     	|  0.00073228     	|
# |  [LightningModule]TwoLayerNet.on_validation_model_eval                                                                                                                                                     	|  4.1178e-05     	|  2              	|  8.2355e-05     	|  0.00061384     	|
# |  [LightningModule]TwoLayerNet.configure_optimizers                                                                                                                                                         	|  5.7969e-05     	|  1              	|  5.7969e-05     	|  0.00043208     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_end                  	|  2.5615e-05     	|  2              	|  5.123e-05      	|  0.00038185     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                                                         	|  1.2004e-05     	|  2              	|  2.4009e-05     	|  0.00017895     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                                                       	|  2.2456e-05     	|  1              	|  2.2456e-05     	|  0.00016738     	|
# |  [LightningModule]TwoLayerNet.on_epoch_start                                                                                                                                                               	|  5.6307e-06     	|  3              	|  1.6892e-05     	|  0.00012591     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                                                                  	|  8.4205e-06     	|  2              	|  1.6841e-05     	|  0.00012553     	|
# |  [LightningModule]TwoLayerNet.on_train_epoch_start                                                                                                                                                         	|  1.634e-05      	|  1              	|  1.634e-05      	|  0.00012179     	|
# |  [LightningModule]TwoLayerNet.on_val_dataloader                                                                                                                                                            	|  1.6318e-05     	|  1              	|  1.6318e-05     	|  0.00012163     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                                                                 	|  1.2771e-05     	|  1              	|  1.2771e-05     	|  9.519e-05      	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                                                                	|  5.5765e-06     	|  2              	|  1.1153e-05     	|  8.313e-05      	|
# |  [Callback]TQDMProgressBar.on_epoch_end                                                                                                                                                                    	|  3.2013e-06     	|  3              	|  9.604e-06      	|  7.1584e-05     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                                                                     	|  9.021e-06      	|  1              	|  9.021e-06      	|  6.7239e-05     	|
# |  [LightningModule]TwoLayerNet.on_train_start                                                                                                                                                               	|  8.492e-06      	|  1              	|  8.492e-06      	|  6.3296e-05     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                                                              	|  8.422e-06      	|  1              	|  8.422e-06      	|  6.2774e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_fit_start                                                                                                                                                      	|  7.938e-06      	|  1              	|  7.938e-06      	|  5.9167e-05     	|
# |  [LightningModule]TwoLayerNet.on_validation_epoch_end                                                                                                                                                      	|  3.838e-06      	|  2              	|  7.676e-06      	|  5.7214e-05     	|
# |  [Callback]TQDMProgressBar.on_epoch_start                                                                                                                                                                  	|  2.3063e-06     	|  3              	|  6.919e-06      	|  5.1571e-05     	|
# |  [LightningModule]TwoLayerNet.on_epoch_end                                                                                                                                                                 	|  1.9373e-06     	|  3              	|  5.812e-06      	|  4.332e-05      	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                                                           	|  5.811e-06      	|  1              	|  5.811e-06      	|  4.3313e-05     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                                                                	|  5.716e-06      	|  1              	|  5.716e-06      	|  4.2605e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_epoch_end                       	|  1.7907e-06     	|  3              	|  5.372e-06      	|  4.0041e-05     	|
# |  [Callback]ModelSummary.on_epoch_end                                                                                                                                                                       	|  1.7857e-06     	|  3              	|  5.357e-06      	|  3.9929e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_start                                                                                                                                         	|  5.344e-06      	|  1              	|  5.344e-06      	|  3.9832e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_end                                                                                                                                                      	|  1.7433e-06     	|  3              	|  5.23e-06       	|  3.8982e-05     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                                                             	|  4.76e-06       	|  1              	|  4.76e-06       	|  3.5479e-05     	|
# |  [Callback]ModelSummary.on_epoch_start                                                                                                                                                                     	|  1.539e-06      	|  3              	|  4.617e-06      	|  3.4413e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_end                                                                                                                                                 	|  2.2395e-06     	|  2              	|  4.479e-06      	|  3.3385e-05     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_start                                                                                                                                                       	|  4.45e-06       	|  1              	|  4.45e-06       	|  3.3168e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_start                                                                                                                                              	|  4.325e-06      	|  1              	|  4.325e-06      	|  3.2237e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                                                               	|  4.245e-06      	|  1              	|  4.245e-06      	|  3.164e-05      	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                                                            	|  2.101e-06      	|  2              	|  4.202e-06      	|  3.132e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_epoch_start                     	|  1.3947e-06     	|  3              	|  4.184e-06      	|  3.1186e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_epoch_start                                                                                                                                                    	|  1.3917e-06     	|  3              	|  4.175e-06      	|  3.1119e-05     	|
# |  [LightningModule]TwoLayerNet.on_train_dataloader                                                                                                                                                          	|  4.088e-06      	|  1              	|  4.088e-06      	|  3.047e-05      	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                                                                    	|  3.818e-06      	|  1              	|  3.818e-06      	|  2.8458e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                                                       	|  1.8735e-06     	|  2              	|  3.747e-06      	|  2.7929e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_start                                                                                                                                               	|  1.858e-06      	|  2              	|  3.716e-06      	|  2.7697e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_epoch_end            	|  1.8575e-06     	|  2              	|  3.715e-06      	|  2.769e-05      	|
# |  [Callback]GradientAccumulationScheduler.on_validation_epoch_end                                                                                                                                           	|  1.8515e-06     	|  2              	|  3.703e-06      	|  2.7601e-05     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                                                      	|  3.482e-06      	|  1              	|  3.482e-06      	|  2.5953e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_start                	|  1.699e-06      	|  2              	|  3.398e-06      	|  2.5327e-05     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                                                              	|  3.299e-06      	|  1              	|  3.299e-06      	|  2.4589e-05     	|
# |  [LightningModule]TwoLayerNet.prepare_data                                                                                                                                                                 	|  3.144e-06      	|  1              	|  3.144e-06      	|  2.3434e-05     	|
# |  [Callback]TQDMProgressBar.on_before_accelerator_backend_setup                                                                                                                                             	|  3.101e-06      	|  1              	|  3.101e-06      	|  2.3114e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                                                          	|  1.521e-06      	|  2              	|  3.042e-06      	|  2.2674e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_validation_epoch_start          	|  1.4725e-06     	|  2              	|  2.945e-06      	|  2.1951e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_validation_epoch_start                                                                                                                                         	|  1.471e-06      	|  2              	|  2.942e-06      	|  2.1928e-05     	|
# |  [Callback]ModelSummary.setup                                                                                                                                                                              	|  2.819e-06      	|  1              	|  2.819e-06      	|  2.1012e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_start                     	|  2.596e-06      	|  1              	|  2.596e-06      	|  1.9349e-05     	|
# |  [Callback]TQDMProgressBar.on_configure_sharded_model                                                                                                                                                      	|  2.37e-06       	|  1              	|  2.37e-06       	|  1.7665e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_train_epoch_end                                                                                                                                                	|  2.306e-06      	|  1              	|  2.306e-06      	|  1.7188e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_fit_start                       	|  2.242e-06      	|  1              	|  2.242e-06      	|  1.6711e-05     	|
# |  [Callback]TQDMProgressBar.on_pretrain_routine_end                                                                                                                                                         	|  2.198e-06      	|  1              	|  2.198e-06      	|  1.6383e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_pretrain_routine_start          	|  2.186e-06      	|  1              	|  2.186e-06      	|  1.6294e-05     	|
# |  [Callback]ModelSummary.on_pretrain_routine_start                                                                                                                                                          	|  2.123e-06      	|  1              	|  2.123e-06      	|  1.5824e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': None}.on_before_accelerator_backend_setup	|  2.12e-06       	|  1              	|  2.12e-06       	|  1.5802e-05     	|
# |  [LightningModule]TwoLayerNet.on_validation_end                                                                                                                                                            	|  1.032e-06      	|  2              	|  2.064e-06      	|  1.5384e-05     	|
# |  [LightningModule]TwoLayerNet.on_validation_start                                                                                                                                                          	|  1.0195e-06     	|  2              	|  2.039e-06      	|  1.5198e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_train_end                                                                                                                                                      	|  2.036e-06      	|  1              	|  2.036e-06      	|  1.5175e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_pretrain_routine_end            	|  2.023e-06      	|  1              	|  2.023e-06      	|  1.5079e-05     	|
# |  [Callback]ModelSummary.on_before_accelerator_backend_setup                                                                                                                                                	|  1.984e-06      	|  1              	|  1.984e-06      	|  1.4788e-05     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                                                                 	|  1.984e-06      	|  1              	|  1.984e-06      	|  1.4788e-05     	|
# |  [Callback]GradientAccumulationScheduler.setup                                                                                                                                                             	|  1.982e-06      	|  1              	|  1.982e-06      	|  1.4773e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_save_checkpoint                 	|  1.98e-06       	|  1              	|  1.98e-06       	|  1.4758e-05     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                                                        	|  1.978e-06      	|  1              	|  1.978e-06      	|  1.4743e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_sanity_check_end                                                                                                                                               	|  1.956e-06      	|  1              	|  1.956e-06      	|  1.4579e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_save_checkpoint                                                                                                                                                	|  1.911e-06      	|  1              	|  1.911e-06      	|  1.4244e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_configure_sharded_model         	|  1.89e-06       	|  1              	|  1.89e-06       	|  1.4087e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_end                       	|  1.881e-06      	|  1              	|  1.881e-06      	|  1.402e-05      	|
# |  [Callback]GradientAccumulationScheduler.on_train_start                                                                                                                                                    	|  1.875e-06      	|  1              	|  1.875e-06      	|  1.3975e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_sanity_check_end                	|  1.841e-06      	|  1              	|  1.841e-06      	|  1.3722e-05     	|
# |  [Callback]ModelSummary.on_configure_sharded_model                                                                                                                                                         	|  1.824e-06      	|  1              	|  1.824e-06      	|  1.3595e-05     	|
# |  [Callback]ModelSummary.on_pretrain_routine_end                                                                                                                                                            	|  1.822e-06      	|  1              	|  1.822e-06      	|  1.358e-05      	|
# |  [Callback]GradientAccumulationScheduler.on_pretrain_routine_end                                                                                                                                           	|  1.81e-06       	|  1              	|  1.81e-06       	|  1.3491e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_before_accelerator_backend_setup                                                                                                                               	|  1.784e-06      	|  1              	|  1.784e-06      	|  1.3297e-05     	|
# |  [Callback]GradientAccumulationScheduler.on_sanity_check_start                                                                                                                                             	|  1.775e-06      	|  1              	|  1.775e-06      	|  1.323e-05      	|
# |  [LightningModule]TwoLayerNet.configure_callbacks                                                                                                                                                          	|  1.724e-06      	|  1              	|  1.724e-06      	|  1.285e-05      	|
# |  [Callback]GradientAccumulationScheduler.on_configure_sharded_model                                                                                                                                        	|  1.705e-06      	|  1              	|  1.705e-06      	|  1.2708e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_sanity_check_start              	|  1.685e-06      	|  1              	|  1.685e-06      	|  1.2559e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_train_epoch_start               	|  1.634e-06      	|  1              	|  1.634e-06      	|  1.2179e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                                                        	|  8.025e-07      	|  2              	|  1.605e-06      	|  1.1963e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                                                          	|  7.695e-07      	|  2              	|  1.539e-06      	|  1.1471e-05     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                                                         	|  1.425e-06      	|  1              	|  1.425e-06      	|  1.0621e-05     	|
# |  [LightningModule]TwoLayerNet.on_validation_epoch_start                                                                                                                                                    	|  7.025e-07      	|  2              	|  1.405e-06      	|  1.0472e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.teardown                           	|  1.344e-06      	|  1              	|  1.344e-06      	|  1.0018e-05     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                                                           	|  1.331e-06      	|  1              	|  1.331e-06      	|  9.9207e-06     	|
# |  [Callback]GradientAccumulationScheduler.on_fit_end                                                                                                                                                        	|  1.272e-06      	|  1              	|  1.272e-06      	|  9.481e-06      	|
# |  [Callback]GradientAccumulationScheduler.teardown                                                                                                                                                          	|  1.233e-06      	|  1              	|  1.233e-06      	|  9.1903e-06     	|
# |  [LightningModule]TwoLayerNet.on_train_epoch_end                                                                                                                                                           	|  1.217e-06      	|  1              	|  1.217e-06      	|  9.071e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None, 'save_on_train_epoch_end': True}.on_fit_end                         	|  1.215e-06      	|  1              	|  1.215e-06      	|  9.0561e-06     	|
# |  [LightningModule]TwoLayerNet.setup                                                                                                                                                                        	|  1.199e-06      	|  1              	|  1.199e-06      	|  8.9368e-06     	|
# |  [LightningModule]TwoLayerNet.on_pretrain_routine_start                                                                                                                                                    	|  1.179e-06      	|  1              	|  1.179e-06      	|  8.7878e-06     	|
# |  [LightningModule]TwoLayerNet.on_fit_end                                                                                                                                                                   	|  1.177e-06      	|  1              	|  1.177e-06      	|  8.7729e-06     	|
# |  [LightningModule]TwoLayerNet.configure_sharded_model                                                                                                                                                      	|  1.134e-06      	|  1              	|  1.134e-06      	|  8.4524e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                                                               	|  1.079e-06      	|  1              	|  1.079e-06      	|  8.0424e-06     	|
# |  [LightningModule]TwoLayerNet.on_fit_start                                                                                                                                                                 	|  1.013e-06      	|  1              	|  1.013e-06      	|  7.5505e-06     	|
# |  [LightningModule]TwoLayerNet.on_save_checkpoint                                                                                                                                                           	|  1.005e-06      	|  1              	|  1.005e-06      	|  7.4908e-06     	|
# |  [LightningModule]TwoLayerNet.on_train_end                                                                                                                                                                 	|  9.46e-07       	|  1              	|  9.46e-07       	|  7.0511e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                                                             	|  7.61e-07       	|  1              	|  7.61e-07       	|  5.6722e-06     	|
# |  [LightningModule]TwoLayerNet.on_pretrain_routine_end                                                                                                                                                      	|  7.2e-07        	|  1              	|  7.2e-07        	|  5.3666e-06     	|
# |  [LightningModule]TwoLayerNet.teardown                                                                                                                                                                     	|  5.96e-07       	|  1              	|  5.96e-07       	|  4.4423e-06     	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# We can see an overview of the time taken for different steps.
# This  enables us to detect bottlenecks in the model more easily. A bottleneck can be, for example, long times in dataloading. It becomes very important later, especially, when you start to implement custom layers or loss functions.

# %% [markdown]
# ### Some more debugging Options
#
# * [`fast_dev_run`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html#fast-dev-run): Runs of batch of each train, validation and test pass (if validation and test datalaoders are passed as arguments).This is a fast way to check if everything works (dataloading, validation metric, model saving/ loading) without having to wait for a full epoch.
#
# * [`track_grad_norm`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html#track-grad-norm): Logs the  norm of the gradients (set to `1` for the $L1$ norm or `2` for the $L2$ norm) for each layer. You can check whether the network is actually doing something. If the gradients are too small or too high, you won't have a good training (due to vanishing/ exploding gradients).
#
#
# ### Other Features
#
# Finally, we want to mention some other useful options in the Trainer class:
#
# * [`resume_from_checkpoint`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html#resume-from-checkpoint): Start the training from a checkpoint saved earlier. Argument is the path to the saved model file.
# * [`Callbacks`](https://pytorch-lightning.readthedocs.io/en/latest/callbacks.html#callback): Callbacks are extremely useful system during training that automate non essential code such as  storing model checkpoints , saving weights values among others.
#
# Let's have the look at the [`EarlyStopping`](https://pytorch-lightning.readthedocs.io/en/latest/early_stopping.html#early-stopping-based-on-metric-using-the-earlystopping-callback)  callback.
#
# It interrupts the training if the `monitor` metric variable does not  improve for `patience` number of epochs.
#
# Below is a code example on how to apply it!
#
# ```python
# from pytorch_lightning.callbacks.early_stopping import EarlyStopping
#
# early_stop_callback = EarlyStopping(
#    monitor='val_accuracy',
#    patience=3,
#    verbose=False,
#    mode='max'
# )
#
# trainer = Trainer(max_epochs=10,callbacks=[early_stop_callback])
# ```
#
# Your journey with pytorch lightning will force you to check out a bunch of callbacks to return the desired functions without having to write the respective code yourself. Or you hack it in, do as you wish :).

# %% [markdown]
# ## References
#
# 1. PyTorch Lightining [`Source Code`](https://github.com/PyTorchLightning/pytorch-lightning) with a nice introduction
# 2. PyTorch Lightining [`Documentation`](https://pytorch-lightning.readthedocs.io/en/latest/#)  Explore it! The features are very well explained.
